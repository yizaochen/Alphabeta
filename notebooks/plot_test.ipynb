# %%
using PyPlot

# %%
x1 = 1:100
y1 = x1

x2 = 35:70
y2 = x2

# %%
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(12,6))

for xavg in  
end

plt.tight_layout()
plt.show()
# Out:
# Figure(PyObject <Figure size 1200x600 with 6 Axes>)
