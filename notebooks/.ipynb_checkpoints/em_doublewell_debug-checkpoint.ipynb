# %%
using Fretem, Potential, Alphabeta, PyPlot, Printf, PhotonOperator, JLD, LinearAlgebra

# %% [markdown]
# ### Part 1: Get collocation points and integration kernel for whole domain

# %%
Nh = 64    # The number of Spectral element
Np = 4     # The order of polynomial which used to interpolate and integration

# Define Physical Domain
xratio = 20 # unit: angstrom
xavg = 50   # unit: angstrom

x, w, Ldx, L = getLagrange(Np, xratio/Nh)
e_norm = x[end] - x[1]
interpo_xs = x .+ x[end]

N, xref, w0, Ldx, w = get_fem_xref_weights_basis(Nh, Np, xratio, xavg);

# %% [markdown]
# ### Part 2: Set $V_{eq}(x)$ and $p_{eq}(x)$

# %%
W = 10
H = 5
d = H
V_eq = doulbe_well_width_height(xref, W, H, xavg, d)
F_eq = force_doulbe_well_width_height(xref, W, H, xavg)
D = 4.845e9 # Diffusion coefficient, unit: angstrom^2 s-1
rho_eq = get_rhoeq(V_eq, w0)
peq = rho_eq .* rho_eq

## Photon Operator
k_photon = 3. # unit: kcal/mol/angstrom^2
sigma_photon = 1 / sqrt(2 * k_photon);

# %% [markdown]
# ### Part 3: Read Trajectory

# %% [markdown]
# #### physical parameters about simulations

# %%
save_freq = 1e-9 # unit: s, Save trajectory per 100 ps
total_times = 10e-6 # unit: s, totol simulate 10 us, 10e-6
dt = 1e-11 # unit: s  # Integration Times 1ps
#kbT = 1
tau = Int(round(total_times / save_freq, digits=0))  # Number of photons
n_interval = Int(round(save_freq / dt, digits=0));

time_info = @sprintf "Save trajectory per %d timesteps. There will be %d data points." n_interval tau
println(time_info)
# Out:
# Save trajectory per 100 timesteps. There will be 10000 data points.

# %% [markdown]
# #### read simulated trajectory from jld file

# %%
# Read simulated trajectory from jld file
f_in = "../trajectory/doublewell_tsim_10us_deltat_1ns.jld"
y_record = load(f_in, "y_record")
t_record = load(f_in, "t_record")
xref = load(f_in, "xref")
rho_eq = load(f_in, "rho_eq")
W = load(f_in, "W")
H = load(f_in, "H")
D = load(f_in, "D");

# %%
fig, axes = plt.subplots(ncols=2, nrows=1, figsize=(12,4))

ax = axes[1]
ax.plot(xref, rho_eq .* rho_eq)
ax.set_xlabel("x (\$ \\AA \$)")
ax.set_ylabel("\$ p_{eq}(x) \$")

ax = axes[2]
ax.plot(t_record, y_record)
ax.set_xlabel("Time (s)")
ax.set_ylabel("x (\$ \\AA \$)")
ax.set_ylim(30,70)
#plt.savefig("Simu_for_EM.png", dpi=200)
plt.show()
# Out:
# Figure(PyObject <Figure size 1200x400 with 2 Axes>)

# %% [markdown]
# ### Part 4: Eigen-decomposition for $p_{\rm eq}$

# %%
Nv = 72 # Number of eigenvectors
LQ, Qx, rho = fem_solve_eigen_by_pref(Nh, Np, xratio, xavg, peq, D, Nv);

# %%
fig, axes = plt.subplots(nrows=3, ncols=4, figsize=(16,12))

idx_eigvector = 1
for row_id=1:3
    for col_id = 1:4
        ax = axes[row_id, col_id]
        plot_x_Qx_lambda(ax, idx_eigvector, LQ, Qx, xref)
        idx_eigvector += 1
    end
end
plt.tight_layout()
#plt.savefig("eigv_1_12_doublewell.png", dpi=150)
plt.show()
# Out:
# Figure(PyObject <Figure size 1600x1200 with 12 Axes>)

# %% [markdown]
# ### Part 5: Get $a_i = \left<\alpha_{t0} | \psi_i \right>$, where $i=1,\cdots,N_v$ and get $p_{appr}$

# %%
a_array = Fretem.get_coefficients_by_proj(w0, rho, Qx, Nv)
weight_Qx = get_weight_Qx(N, Nv, w0, Qx)
alpha_t0 = get_alpha_t0(weight_Qx, rho)
#p0_appr = Fretem.rebuild_p0_by_Qx_carray(Nv, a_array, Qx, rho_eq)
#p0_appr = p0_appr / sum(w0 .* p0_appr);

# %%
norm(alpha_t0)
# Out:
# 0.07198157507486933

# %%
sum(w0 .* p0_appr)
# Out:
# 0.9999999999999992

# %%
fig, axes = plt.subplots(ncols=2, nrows=1, figsize=(16,6))

ax = axes[1]
ax.plot(xref, rho_eq, color="blue", alpha=0.6, label="analytical")
ax.plot(xref, -Qx[:, 1], color="red", alpha=0.6, label="approximation")
ax.legend()
ax.set_xlabel("x", fontsize=14)
ax.set_ylabel("\$ p_0(x) \$", fontsize=14)

plt.show()
# Out:
# Figure(PyObject <Figure size 1600x600 with 2 Axes>)

# %% [markdown]
# ### Part 6: $\rho_{appr}(x) = a_1 \psi_1(x)+ a_2 \psi_2(x)+\cdots+ a_n \psi_n(x) $

# %%
Nv_sele = 72
N = size(Qx)[1]
rho0_appr = zeros(N)
for idx_eigv in 1:Nv_sele
    rho0_appr = rho0_appr .+ (a_array[idx_eigv] .* Qx[:, idx_eigv])
end

# %%
fig, axes = plt.subplots(ncols=2, nrows=1, figsize=(16,6))

ax = axes[1]
ax.plot(xref, peq, color="blue", alpha=0.6, label="analytical")
ax.plot(xref, p0_appr, color="red", alpha=0.6, label="approximation")
ax.legend()
ax.set_xlabel("x", fontsize=14)
ax.set_ylabel("\$ p_0(x) \$", fontsize=14)

plt.show()
# Out:
# Figure(PyObject <Figure size 1600x600 with 2 Axes>)

# %%
fig, axes = plt.subplots(ncols=2, nrows=1, figsize=(16,6))

ax = axes[1]
ax.plot(xref, rho_eq, color="blue", alpha=0.6, label="analytical")
ax.plot(xref, rho0_appr, color="red", alpha=0.6, label="approximation")
ax.legend()
ax.set_xlabel("x", fontsize=14)
ax.set_ylabel("\$ \\rho_0(x) \$", fontsize=14)

w = 0.4
xlist = 1:72
xticks = 1:2:35
ax = axes[2]
ax.bar(xlist, abs.(a_array), w)
#ax.set_xticks(xticks)
#ax.set_ylabel("\$ a_n \$", fontsize=14)
#ax.set_xlabel("n", fontsize=14)

#figname = @sprintf "appr_k0_%.2f.png" k0
#plt.savefig(figname, dpi=100)

plt.show()
# Out:
# Figure(PyObject <Figure size 1600x600 with 2 Axes>)
