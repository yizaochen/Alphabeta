# %%
using Fretem, Potential, Alphabeta, PyPlot, Printf, PhotonOperator, JLD, LinearAlgebra

# %% [markdown]
# ### Part 1: Get collocation points and integration kernel for whole domain

# %%
Nh = 64    # The number of Spectral element
Np = 4     # The order of polynomial which used to interpolate and integration
Nv = 72

# Define Physical Domain
xratio = 20. # unit: angstrom
xavg = 50.   # unit: angstrom

x, w, Ldx, L = getLagrange(Np, xratio/Nh)
e_norm = x[end] - x[1]
interpo_xs = x .+ x[end]

N, xref, w0, Ldx, w = get_fem_xref_weights_basis(Nh, Np, xratio, xavg);

# %% [markdown]
# ### Part 2: Set $V_{eq}(x)$ and $p_{eq}(x)$

# %%
k_eq = 0.5 # unit: kcal/mol/angstrom^2
sigma_by_keq = 1 / sqrt(2 * k_eq)
V_eq = harmonic_well_k_mean(xref, k_eq, xavg)
rho_eq = get_rhoeq(V_eq, w0)
peq = rho_eq .* rho_eq
D = 4.845e9 # Diffusion coefficient, unit: angstrom^2 s-1
## Photon Operator
k_photon = 3. # unit: kcal/mol/angstrom^2
sigma_photon = 1 / sqrt(2 * k_photon);

# %% [markdown]
# ### Part 3: Read Trajectory

# %% [markdown]
# #### physical parameters about simulations

# %%
save_freq = 1e-9 # unit: s, Save trajectory per 100 ps
total_times = 10e-6 # unit: s, totol simulate 10 us, 10e-6
dt = 1e-11 # unit: s  # Integration Times 1ps
#kbT = 1
tau = Int(round(total_times / save_freq, digits=0))  # Number of photons
n_interval = Int(round(save_freq / dt, digits=0));

time_info = @sprintf "Save trajectory per %d timesteps. There will be %d data points." n_interval tau
println(time_info)
# Out:
# Save trajectory per 100 timesteps. There will be 10000 data points.

# %% [markdown]
# #### read simulated trajectory from jld file

# %%
f_in = "../trajectory/k_1_tsim_10us_deltat_1ns.jld"
y_record = load(f_in, "y_record")
t_record = load(f_in, "t_record")
xref = load(f_in, "xref")
rho_eq = load(f_in, "rho_eq")
k_ref = load(f_in, "k_ref")
D = load(f_in, "D"); # Diffusion coefficient, unit: angstrom^2 s-1

# %% [markdown]
# ### Part 4: Gaussian KDE estimation

# %%
peq_kde_estimate = gaussian_kde(xref, y_record, sigma_by_keq, w0);

# %%
fig, axes = plt.subplots(ncols=2, nrows=1, figsize=(12,4))

ax = axes[1]
ax.plot(xref, rho_eq .* rho_eq, label="True")
ax.plot(xref, peq_kde_estimate, label="Gaussian KDE: \$\\sigma=1.0 \$")
ax.set_xlabel("x (\$ \\AA \$)")
ax.set_ylabel("\$ p_{eq}(x) \$")
ax.legend()


ax = axes[2]
ax.plot(t_record, y_record)
ax.set_xlabel("Time (s)")
ax.set_ylabel("x (\$ \\AA \$)")
ax.set_ylim(30,70)

plt.tight_layout()
#plt.savefig("Gaussian_Kde_harmonic_well.svg")
plt.show()
# Out:
# Figure(PyObject <Figure size 1200x400 with 2 Axes>)

# %% [markdown]
# ### Part: EM

# %%
n_iteration = 20
p_container = zeros(Float64, n_iteration+1, N)
log_likelihood_records = zeros(n_iteration+1)
        
# Iteration of EM
p_prev = max.(peq_kde_estimate, 1e-10)  # initial guess
p_container[1, :] = max.(peq_kde_estimate, 1e-10) # The first row in container is p0
for iter_id = 1:n_iteration
    println(@sprintf "Iteration-ID: %d" iter_id)
    p_em, log_likelihood = forward_backward_v2(Nh, Np, xratio, xavg, p_prev, D, Nv, tau, y_record, save_freq, k_photon)
    p_em = max.(p_em, 1e-10)   
    p_container[iter_id+1, :] = p_em    
    p_prev[:,1] = p_em
    log_likelihood_records[iter_id] = log_likelihood
end
# Out:
# Iteration-ID: 1
# Iteration-ID: 2
# Iteration-ID: 3
# Iteration-ID: 4
# Iteration-ID: 5
# Iteration-ID: 6
# Iteration-ID: 7
# Iteration-ID: 8
# Iteration-ID: 9
# Iteration-ID: 10
# Iteration-ID: 11
# Iteration-ID: 12
# Iteration-ID: 13
# Iteration-ID: 14
# Iteration-ID: 15
# Iteration-ID: 16
# Iteration-ID: 17
# Iteration-ID: 18
# Iteration-ID: 19
# Iteration-ID: 20

# %%
em_id_sele = 20

fig, ax = plt.subplots(ncols=1, nrows=1, figsize=(8,4))

ax.plot(xref, rho_eq .* rho_eq, label="True")
ax.plot(xref, p_container[em_id_sele, :], label="EM after KDE")
ax.set_xlabel("x (\$ \\AA \$)")
ax.set_ylabel("\$ p_{eq}(x) \$")
ax.legend()

plt.tight_layout()
plt.show()
# Out:
# Figure(PyObject <Figure size 800x400 with 1 Axes>)

# %% [markdown]
# ### Part 5: Eigendecomposition for KDE estimation

# %%
Nv = 72 # Number of eigenvectors
LQ, Qx, rho = fem_solve_eigen_by_pref(Nh, Np, xratio, xavg, peq_kde_estimate, D, Nv);

# %% [markdown]
# Inspect 1-12 eigenvectors

# %%
fig, axes = plt.subplots(nrows=3, ncols=4, figsize=(16,12))

idx_eigvector = 1
for row_id=1:3
    for col_id = 1:4
        ax = axes[row_id, col_id]
        plot_x_Qx_lambda(ax, idx_eigvector, LQ, Qx, xref)
        idx_eigvector += 1
    end
end
plt.tight_layout()
#plt.savefig("eigv_1_12.png", dpi=150)
plt.show()
# Out:
# Figure(PyObject <Figure size 1600x1200 with 12 Axes>)

# %% [markdown]
# ### Part 6: EM-1

# %%
p_em_1, log_likelihood = forward_backward_v2(Nh, Np, xratio, xavg, peq_kde_estimate, D, Nv, tau, y_record, save_freq);

# %%
fig, ax = plt.subplots(ncols=1, nrows=1, figsize=(8,4))

ax.plot(xref, rho_eq .* rho_eq, label="True")
ax.plot(xref, p_em_1, label="EM-1 after KDE")
ax.set_xlabel("x (\$ \\AA \$)")
ax.set_ylabel("\$ p_{eq}(x) \$")
ax.legend()

plt.tight_layout()
plt.show()
# Out:
# Figure(PyObject <Figure size 800x400 with 1 Axes>)

# %% [markdown]
# ### Part 7: EM-2

# %%
p_em_1 = max.(p_em_1, 1e-10)
p_prev = zeros(N, 1)
p_prev[:,1] = p_em_1;

# %%
p_em_2, log_likelihood = forward_backward_v2(Nh, Np, xratio, xavg, p_prev, D, Nv, tau, y_record, save_freq);

# %%
fig, ax = plt.subplots(ncols=1, nrows=1, figsize=(8,4))

ax.plot(xref, rho_eq .* rho_eq, label="True")
ax.plot(xref, p_em_2, label="EM-2 after KDE")
ax.set_xlabel("x (\$ \\AA \$)")
ax.set_ylabel("\$ p_{eq}(x) \$")
ax.legend()

plt.tight_layout()
plt.show()
# Out:
# Figure(PyObject <Figure size 800x400 with 1 Axes>)

# %%
a = 50. # unit: Å
D = get_D_by_Stokes_Einstein_relation(a)
# Out:
# UndefVarError: get_D_by_Stokes_Einstein_relation not defined
#
# Stacktrace:
#  [1] top-level scope at In[22]:2
#  [2] include_string(::Function, ::Module, ::String, ::String) at ./loading.jl:1091
#  [3] execute_code(::String, ::String) at /home/yizaochen/.julia/packages/IJulia/rWZ9e/src/execute_request.jl:27
#  [4] execute_request(::ZMQ.Socket, ::IJulia.Msg) at /home/yizaochen/.julia/packages/IJulia/rWZ9e/src/execute_request.jl:86
#  [5] #invokelatest#1 at ./essentials.jl:710 [inlined]
#  [6] invokelatest at ./essentials.jl:709 [inlined]
#  [7] eventloop(::ZMQ.Socket) at /home/yizaochen/.julia/packages/IJulia/rWZ9e/src/eventloop.jl:8
#  [8] (::IJulia.var"#15#18")() at ./task.jl:356
